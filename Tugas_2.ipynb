# %% [markdown]
# <a href="https://colab.research.google.com/github/jericohenderson/Binus-Python/blob/main/Tugas_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = {
    "Country": ["Indonesia", "Japan", "India", "China", "United States", "Brazil", "Russia", "UK", "UAE", "Saudi Arabia"],
    "Capital": ["Jakarta", "Tokyo", "New Delhi", "Beijing", "Washington DC", "Brasilia", "Moscow", "London", "Dubai", "Riyadh"],
    "Continent": ["Asia", "Asia", "Asia", "Asia", "America", "America", "Asia", "Europe", "Asia", "Asia"],
    "Area": [1905, 377, 3287, 9597, 9834, 8515, 17098, 243, 836, 215],
    "Population": [264, 143, 1252, 1357, 329, 210, 146, 699, 1100, 1600]
}


df = pd.DataFrame(data)
mean = df.Population.mean()
std = df.Area.std()

print(df)
print(mean)
print(std)
# Out:
#          Country        Capital Continent   Area  Population
# 0      Indonesia        Jakarta      Asia   1905         264
# 1          Japan          Tokyo      Asia    377         143
# 2          India      New Delhi      Asia   3287        1252
# 3          China        Beijing      Asia   9597        1357
# 4  United States  Washington DC   America   9834         329
# 5         Brazil       Brasilia   America   8515         210
# 6         Russia         Moscow      Asia  17098         146
# 7             UK         London    Europe    243         699
# 8            UAE          Dubai      Asia    836        1100
# 9   Saudi Arabia         Riyadh      Asia    215        1600
# 710.0
# 5769.679579972839
