# %% [markdown]
# <a href="https://colab.research.google.com/github/jericohenderson/Binus-Python/blob/main/Tugas_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def write_biodata(filename):
    """Handles user input and writes it to the file."""
    name = input("Enter Name: ")
    age = input("Enter Age: ")
    address = input("Enter Address: ")
    email = input("Enter Email: ")

    try:
        with open(filename, 'w') as file:
            file.write(f"Name: {name}\n")
            file.write(f"Age: {age}\n")
            file.write(f"Address: {address}\n")
            file.write(f"Email: {email}\n")
        print(f"\nData successfully saved to {filename}")
    except IOError as e:
        print(f"An error occurred while writing to the file: {e}")

def read_biodata(filename):
    """Reads and displays the content of the file."""
    print("\n--- Displaying Content of Biodata.txt ---")
    try:
        with open(filename, 'r') as file:
            content = file.read()
            print(content)
    except FileNotFoundError:
        print("Error: The file does not exist.")
    except IOError as e:
        print(f"An error occurred while reading the file: {e}")

# Main execution
if __name__ == "__main__":
    file_name = "Biodata.txt"
    write_biodata(file_name)
    read_biodata(file_name)
# Out:
# Enter Name: Jerico
# Enter Age: 19
# Enter Address: Jalan Pinang Kuningan XI
# Enter Email: jericohenderson.id@gmail.com
#
# Data successfully saved to Biodata.txt
#
# --- Displaying Content of Biodata.txt ---
# Name: Jerico
# Age: 19
# Address: Jalan Pinang Kuningan XI
# Email: jericohenderson.id@gmail.com
