# %% [markdown]
# <a href="https://colab.research.google.com/github/jericohenderson/Binus-Python/blob/main/Tugas_4_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def create_file(filename):
    """Creates a new file or overwrites an existing one."""
    try:
        with open(filename, 'w') as f:
            print(f"File '{filename}' has been created.")
    except IOError as e:
        print(f"Error creating file: {e}")

def read_file(filename):
    """Reads and prints the content of the specified file."""
    try:
        with open(filename, 'r') as f:
            print(f"\n--- Content of {filename} ---")
            print(f.read())
            print("-----------------------")
    except FileNotFoundError:
        print("Error: That file does not exist.")
    except IOError as e:
        print(f"Error reading file: {e}")

def append_to_file(filename):
    """Appends user-provided text to the end of the file."""
    content = input("Enter the text you want to add: ")
    try:
        with open(filename, 'a') as f:
            f.write(content + '\n')
            print("Data successfully appended.")
    except IOError as e:
        print(f"Error appending to file: {e}")

def main():
    while True:
        print("\n===== FILE MANAGEMENT SYSTEM =====")
        print("1. Create File")
        print("2. Read File")
        print("3. Append to File")
        print("4. Close")

        choice = input("Select an option (1-4): ").strip().lower()

        if choice == '4' or choice == 'close':
            print("Closing program. Goodbye!")
            break

        if choice in ['1', '2', '3']:
            name = input("Enter the filename (including extension, e.g., notes.txt): ")

            if choice == '1':
                create_file(name)
            elif choice == '2':
                read_file(name)
            elif choice == '3':
                append_to_file(name)
        else:
            print("Invalid selection. Please choose 1, 2, 3, or 'close'.")

if __name__ == "__main__":
    main()
# Out:
# ===== FILE MANAGEMENT SYSTEM =====
# 1. Create File
# 2. Read File
# 3. Append to File
# 4. Close
# Select an option (1-4): 1
# Enter the filename (including extension, e.g., notes.txt): Biodata.txt
# File 'Biodata.txt' has been created.
#
# ===== FILE MANAGEMENT SYSTEM =====
# 1. Create File
# 2. Read File
# 3. Append to File
# 4. Close
# Select an option (1-4): 3
# Enter the filename (including extension, e.g., notes.txt): later.txt
# Enter the text you want to add: Hello world
# Data successfully appended.
#
# ===== FILE MANAGEMENT SYSTEM =====
# 1. Create File
# 2. Read File
# 3. Append to File
# 4. Close
# Select an option (1-4): 2
# Enter the filename (including extension, e.g., notes.txt): later.txt
#
# --- Content of later.txt ---
# Hello world
#
# -----------------------
#
# ===== FILE MANAGEMENT SYSTEM =====
# 1. Create File
# 2. Read File
# 3. Append to File
# 4. Close
# Select an option (1-4): Close
# Closing program. Goodbye!
